# %% [markdown]
# # **Q0.Import libraries.**

# %%
import pandas as pd

# %% [markdown]
# # **Q1.Load the CSV using Pandas.**
# df=pd.read_csv("/content/Practice.csv")

# %%
df=pd.read_csv("/content/Practice.csv")

# %% [markdown]
# # **Q2.How many rows and columns are there?**
# 15 rows and 8 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order_ID  15 non-null     int64
#  1   Date      15 non-null     object
#  2   Product   15 non-null     object
#  3   Category  15 non-null     object
#  4   City      15 non-null     object
#  5   Quantity  15 non-null     int64
#  6   Price     15 non-null     int64
#  7   Rating    15 non-null     float64
#  8   Payment   15 non-null     object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.2+ KB

# %% [markdown]
# # **Q3.What are the column names?**
# 'Order_ID',
#  'Date',
#  'Product',
#  'Category',
#  'City',
#  'Quantity',
#  'Price',
#  'Rating',
#  'Payment'

# %%
list(df.columns)
# Out:
# ['Order_ID',
#  'Date',
#  'Product',
#  'Category',
#  'City',
#  'Quantity',
#  'Price',
#  'Rating',
#  'Payment']

# %% [markdown]
# # **Q4.Are there any missing values?**
# no

# %%
df.isnull().sum()
# Out:
# Order_ID    0
# Date        0
# Product     0
# Category    0
# City        0
# Quantity    0
# Price       0
# Rating      0
# Payment     0
# dtype: int64

# %% [markdown]
# # **Q5.What is the average product rating?**
# 4.24

# %%
df["Rating"].mean()
# Out:
# np.float64(4.24)

# %% [markdown]
# # **Q6.What is the total quantity of products sold?**
# 25

# %%
df["Quantity"].sum()
# Out:
# np.int64(25)

# %% [markdown]
# # **Q7.What is the average order value?**
# 13,110

# %%
df["Price"].mean()
# Out:
# np.float64(13110.0)

# %% [markdown]
# # **Q8.Create a new column called 'Sales'.**
# df["Sales"]=df["Quantity"]*df["Price"]

# %%
df["Sales"]=df["Quantity"]*df["Price"]

# %% [markdown]
# # **Q9.What is the total revenue?**
# 210,900

# %%
total_revenue=df["Sales"].sum()
total_revenue
# Out:
# np.int64(210900)

# %% [markdown]
# # **Q10.Which product generated the highest revenue?**
# Laptop	173,000

# %%
df.groupby("Product")["Sales"].sum()
# Out:
# Product
# Headphones      7800
# Keyboard        5200
# Laptop        173000
# Mouse           3900
# Shoes          12700
# T-Shirt         8300
# Name: Sales, dtype: int64

# %% [markdown]
# # **Q11.Which city generated the highest revenue?**
# Pune	71,100

# %%
df.groupby("City")["Sales"].sum()
# Out:
# City
# Delhi     69100
# Mumbai    70700
# Pune      71100
# Name: Sales, dtype: int64

# %% [markdown]
# # **Q12.What is the total revenue from Electronics?**
# Electronics	189,900

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Electronics    189900
# Fashion         21000
# Name: Sales, dtype: int64

# %% [markdown]
# # **Q13.What is the total revenue from Fashion?**
# Fashion	21,000

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Electronics    189900
# Fashion         21000
# Name: Sales, dtype: int64

# %% [markdown]
# # **Q14.Which payment method was used most frequently?**
# UPI	6

# %%
df.groupby("Payment")["Payment"].count()
# Out:
# Payment
# Card    5
# Cash    4
# UPI     6
# Name: Payment, dtype: int64

# %% [markdown]
# # **Q15.What is the average quantity per order?**
# 1.7

# %%
round(df["Quantity"].mean(),1)
# Out:
# np.float64(1.7)
